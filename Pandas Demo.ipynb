# %%
import pandas as pd

# %%
df = pd.read_csv('DATASET/background survey.csv')

# %%
df.head()
# Out:
#                     Timestamp What is your name?  \
# 0   2026/01/11 7:00:22 PM EST       First Last 1
# 1   2026/01/11 7:52:56 PM EST            First 2
# 2   2026/01/11 8:29:18 PM EST       First Last 3
# 3  2026/01/12 12:45:08 AM EST       First Last 4
# 4   2026/01/12 8:43:02 AM EST       First Last 5
#
#   Did you grow up in North Carolina?  How old are you?  \
# 0                                Yes                20
# 1                                Yes                23
# 2                                 No                21
# 3                                Yes                20
# 4                                Yes                20
#
#   What level of a student are you?  How familiar are you with "data science"?  \
# 0                        Sophomore                                          3
# 1                           Junior                                          2
# 2                           Junior                                          4
# ...

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %% [markdown]
# Types of questions"
# - Average age of student?
# - General feelings of the class?
# - With lower level of familarity --> maybe a slower approach
# - Correctlations between data science and social science.
# - General views on AI --> syllabus
# - On average what time did students submit this?
# - How far along is someone in their program?
#
# Possible cleaning:
# - Clean the answers to question "What is your name?" to where they all say First Last #
# - If no names, no identifer, what do we do about this?
# - "are you excited" could drop this column or convert to numerical value
# - How do we handle duplicates?
# - 'did you grow up in North Carolina' could be boolean
# - consider questions in the open ended text features and how to handle them
